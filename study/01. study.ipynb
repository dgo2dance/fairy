# %%
# %matplotlib inline

# standard
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import seaborn as sns
sns.set()
sns.set_context('notebook', font_scale=1.5)
cp = sns.color_palette()
ts = pd.read_csv('D:/02.Work/22.python/04.Visualization/py-viz-blog/data/ts.csv')

# casting to datetime is important for
# ensuring plots "just work"
ts = ts.assign(dt = pd.to_datetime(ts.dt))
ts.head()
# Out:
#           dt kind     value
# 0 2000-01-01    A  1.442521
# 1 2000-01-02    A  1.981290
# 2 2000-01-03    A  1.586494
# 3 2000-01-04    A  1.378969
# 4 2000-01-05    A -0.277937

# %%
dfp = ts.pivot(index='dt', columns='kind', values='value')
dfp.head()
# Out:
# kind               A         B         C         D
# dt
# 2000-01-01  1.442521  1.808741  0.437415  0.096980
# 2000-01-02  1.981290  2.277020  0.706127 -1.523108
# 2000-01-03  1.586494  3.474392  1.358063 -3.100735
# 2000-01-04  1.378969  2.906132  0.262223 -2.660599
# 2000-01-05 -0.277937  3.489553  0.796743 -3.417402

# %%
fig, ax = plt.subplots(1, 1,
                       figsize=(8, 5))

for k in ts.kind.unique():
    tmp = ts[ts.kind == k]
    ax.plot(tmp.dt, tmp.value, label=k)

ax.set(xlabel='Date',
       ylabel='Value',
       title='Random Timeseries')    
    
ax.legend(loc=2)
fig.autofmt_xdate()

# %%
fig, ax = plt.subplots(1, 1,
                       figsize=(7.5, 5))

ax.plot(dfp)

ax.set(xlabel='Date',
       ylabel='Value',
       title='Random Timeseries')

ax.legend(dfp.columns, loc=2)
fig.autofmt_xdate()

# %%
g = sns.FacetGrid(ts, hue='kind', size=5, aspect=1.5)
g.map(plt.plot, 'dt', 'value').add_legend()
g.ax.set(xlabel='Date',
         ylabel='Value',
         title='Random Timeseries')
g.fig.autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c15503c8a8c6> in <module>()
# ----> 1 g = sns.FacetGrid(ts, hue='kind', size=5, aspect=1.5)
#       2 g.map(plt.plot, 'dt', 'value').add_legend()
#       3 g.ax.set(xlabel='Date',
#       4          ylabel='Value',
#       5          title='Random Timeseries')
#
# NameError: name 'sns' is not defined
